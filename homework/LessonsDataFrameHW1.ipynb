# %% [markdown]
# # HW1. Структура данных DataFrame

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# **Задача 1**. Создайте *DataFrame* из словаря и выведите на экран (через `print()`).

# %%
data = {
    "имя": ["Александр", "Екатерина", "Дмитрий"],
    "возраст": [28, 35, 22],
    "город": ["Москва", "Санкт-Петербург", "Новосибирск"]
}

# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задача 2**.
#   1. Создайте *DataFrame* из списка ниже.
#   2. Задайте имена столбцов: `["Тип", "Сорт", "Год", "Цена"]`.
#   3. Выведите на экран полученный *DataFrame* (через `print()`).

# %%
data = [
    ["Красное", "Седое", 2015, 65000],
    ["Белое", "Сухое", 2018, 45000],
    ["Розовое", "Полусухое", 2020, 52000]
]

# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задача 3**. Создайте *DataFrame* из следующих данных:

# %%
data = {
    "Фильм": ["Форсаж", "Аватар", "Титаник"],
    "Год": [2001, 2009, 1997],
    "Бюджет_млн": [38, 237, 200],
    "Сборы_млн": [207, 2847, 2200]
}

# %% [markdown]
# Используя атрибуты и методы:
# - Выведите количество строк и столбцов
# - Выведите типы данных
# - Выведите первые 2 строки

# %%
# Продолжите написание кода в данной ячейки
# ...
