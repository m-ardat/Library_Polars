# %% [markdown]
# **Задача №4. Определение периодов аренды.**
#
# Для клиента `customer_id = 4` найдите все периоды, когда был хотя бы один взятый напрокат фильм. Выведите таблицу результатов со столбцами:
# - `period_id` - порядковый номер периода,
# - `from_date` - дата начала периода аренды,
# - `to_date` - дата конца периода аренды.

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl
from datetime import datetime, timedelta

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/rental.csv"

df_rental = pl.read_csv(sourse)
df_rental = df_rental.with_columns(
    pl.col("rental_date", "return_date", "last_update").str.strptime(pl.Datetime)
)

df_rental.head(4)

# %%
# Продолжите решение здесь
