# %% [markdown]
# # HW4. Статистические методы (дополнение)

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/diamonds.csv"

# %% [markdown]
# Прочтём *DataFrame* из CSV-файла по ссылке, указанной в переменной `sourse`, и отобразим его.

# %%
df = pl.read_csv(sourse)

print(df.head(4))
# Out:
# shape: (4, 11)
# ┌─────┬───────┬─────────┬───────┬───┬───────┬──────┬──────┬──────┐
# │     ┆ carat ┆ cut     ┆ color ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ --- ┆ ---   ┆ ---     ┆ ---   ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ i64 ┆ f64   ┆ str     ┆ str   ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═════╪═══════╪═════════╪═══════╪═══╪═══════╪══════╪══════╪══════╡
# │ 1   ┆ 0.23  ┆ Ideal   ┆ E     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 2   ┆ 0.21  ┆ Premium ┆ E     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 3   ┆ 0.23  ┆ Good    ┆ E     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 4   ┆ 0.29  ┆ Premium ┆ I     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# └─────┴───────┴─────────┴───────┴───┴───────┴──────┴──────┴──────┘

# %% [markdown]
# В этом домашнем задании будем работать с одним из классических наборов данных в статистике, содержащим информацию о бриллиантах. Описание можно посмотреть [здесь](https://www.kaggle.com/datasets/shivam2503/diamonds).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Краткое описание данных:
# - **price**: цена в долларах США
# - **carat**: вес алмаза
# - **cut**: качество огранки
# - **color**: цвет алмаза
# - **clarity**: измерение прозрачности алмаза
# - **x**: длина в мм
# - **y**: ширина в мм
# - **z**: глубина в мм
# - **depth**: глубина
# - **table**: ширина верхней части алмаза относительно самой широкой точки

# %% [markdown]
# **Задание №1**. Посчитайте корреляцию между весом (carat) и ценой (price)

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №2**. Посчитайте асимметрию (skew) для каратности.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №3**. Посчитайте эксцесс (kurtosis) для цены.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №4**. Постройте матрицу корреляций для всех числовых столбцов.

# %%
# Продолжите написание кода в данной ячейки
# ...
