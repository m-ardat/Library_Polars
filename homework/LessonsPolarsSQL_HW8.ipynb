# %% [markdown]
# # HW8. Операции над множествами

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# Генерация данных

# %%
store_a = pl.DataFrame({
    "product_id": [101, 102, 103, 104, 105],
    "product_name": ["Laptop", "Mouse", "Keyboard", "Monitor", "Tablet"],
    "category": ["Electronics", "Accessories", "Accessories", "Electronics", "Electronics"],
    "sales_amount": [1200, 25, 75, 300, 500],
    "date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"]
})

store_b = pl.DataFrame({
    "product_id": [102, 103, 106, 107, 108],
    "product_name": ["Mouse", "Keyboard", "Charger", "Headphones", "Phone"],
    "category": ["Accessories", "Accessories", "Accessories", "Accessories", "Electronics"],
    "sales_amount": [30, 80, 20, 150, 800],
    "date": ["2025-01-02", "2025-01-03", "2025-01-06", "2025-01-07", "2025-01-08"]
})

# %% [markdown]
# Выведем первые 4 строки

# %%
print(store_a.head(4))
print(store_b.head(4))

# %% [markdown]
# **Задание №1**.
#
# Найти все уникальные товары, проданные в обоих магазинах (независимо от суммы или даты).
# Используйте `UNION`.

# %%
with pl.SQLContext(store_a=store_a, store_b=store_b, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)
# Продолжите написание кода в данной ячейке

# %% [markdown]
# **Задание №2**.
#
# Найти товары, которые продавались в каждом магазине.
# Используйте `INTERSECT`.

# %%
with pl.SQLContext(store_a=store_a, store_b=store_b, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)
# Продолжите написание кода в данной ячейке

# %% [markdown]
# **Задание №3.**
#
# Найти товары, которые продавались только в магазине A, но не в B.
# Используйте `EXCEPT`.

# %%
with pl.SQLContext(store_a=store_a, store_b=store_b, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)
# Продолжите написание кода в данной ячейке

# %% [markdown]
# **Задание №4.**
#
# Объедините данные по обоим магазинам, добавив столбец `store`, обозначающий, из какого магазина данные. Затем найдите все продажи, где сумма больше 100, и отсортируйте по `sales_amount` по убыванию.

# %%
with pl.SQLContext(store_a=store_a, store_b=store_b, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)
# Продолжите написание кода в данной ячейке
