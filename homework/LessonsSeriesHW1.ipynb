# %% [markdown]
# # HW1. Структура данных Series

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl
import numpy as np

# %% [markdown]
# **Задание №1.**
#
# Создайте пустой объект `Series` и выведите его на печать. Наименование переменной может быть любое, на ваше усмотрение.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №2.**
#
# Есть список натуральных чисел. Создайте на основе этого списка объект `Series` и выведите его на печать.

# %%
# Список
lst = [34, 57, 5, 24, 1, 8, 9]

# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №3.**
#
# Есть словарь с видами тюленей и их кол-ве (ключ - вид тюленя, значение - количество) одного морского зоопарка. Создайте на основе данного словаря два объекта `Series` и выведите их на печать. В первой серии значения должны быть "вид тюленя", во второй - кол-во тюленей.

# %%
# Словарь с тюленями
dict_seals = {
    'морской лев': 12,
    'нерпа': 7,
    'тюлень-монах': 5,
    'императорский тюлень': 9,
    'белька': 4
}

# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №4.**
#
# Есть *NumPy* массив. Создайте на основе данного массива объекта `Series` и выведите на печать.

# %%
# NumPy массив
arr = np.array([1.5, np.nan, 3.2, 4.0, np.nan, 2.7])

# Продолжите написание кода в данной ячейки
# ...
