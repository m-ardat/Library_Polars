# %% [markdown]
# # HW9. Операции соединений

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# **Задание №1**.
#
# Есть таблицы продаж и сотрудников. Найдите всех сотрудников, у которых нет продаж, используя соединение.
# Используя `LEFT ANTI JOIN`, выведите сотрудников, у которых нет записей в таблице продаж.

# %%
sales = pl.DataFrame({
    "employee_id": [101, 102, 104],
    "product": ["laptop", "mouse", "keyboard"],
    "amount": [1200, 25, 80]
})

employees = pl.DataFrame({
    "employee_id": [101, 102, 103, 104],
    "name": ["Анна", "Борис", "Света", "Дмитрий"]
})

with pl.SQLContext(sales=sales, employees=employees, eager=True) as ctx:
    result = ctx.execute("""
    -- Продолжите написание кода здесь

    """)
# Продолжите написание кода в данной ячейке

# %% [markdown]
# **Задание №2**.
#
# Объедините таблицу заказов с таблицей клиентов. Включите в результат всех клиентов, даже если у них нет заказов.
# Используя `LEFT JOIN`, выведите имена всех клиентов и даты их заказов.

# %%
customers = pl.DataFrame({
    "customer_id": [1, 2, 3],
    "customer_name": ["Клиент A", "Клиент B", "Клиент C"]
})

orders = pl.DataFrame({
    "customer_id": [1, 1, 2],
    "order_date": ["2023-01-10", "2023-01-15", "2023-02-01"],
    "total": [100, 150, 200]
})

with pl.SQLContext(customers=customers, orders=orders, eager=True) as ctx:
    result = ctx.execute("""
    -- Продолжите написание кода здесь

    """)

# Продолжите написание кода в данной ячейке

# %% [markdown]
# **Задание №3.**
#
# У вас есть таблицы товаров и поставок. Найдите товары, которые не были поставлены (т.е. отсутствуют в таблице поставок), используя `LEFT ANTI JOIN`. Выведите названия товаров, которые не фигурируют в таблице поставок.

# %%
products = pl.DataFrame({
    "product_id": [10, 20, 30, 40],
    "product_name": ["Товар A", "Товар B", "Товар C", "Товар D"]
})

supplies = pl.DataFrame({
    "product_id": [10, 30, 50],
    "supplier": ["Поставщик X", "Поставщик Y", "Поставщик Z"]
})

with pl.SQLContext(products=products, supplies=supplies, eager=True) as ctx:
    result = ctx.execute("""
    -- Продолжите написание кода здесь

    """)

# Продолжите написание кода в данной ячейке
