# %% [markdown]
# **Задача №2. Ближайшие магазины.**
#
# Имеем таблицу с магазинами:
# - `id` - индентификатор магазина,
# - `latitude` - широта,
# - `longitude` - долгота.
#
# Для каждого магазина получите 4 ближайших (по Евклидовому расстоянию) к нему магазина.
#
# **Примечание.**
# Евклидово расстояние — это метрика, используемая для измерения "прямого" расстояния между двумя точками в пространстве. В двумерном пространстве, если у вас есть две точки с координатами, евклидово расстояние рассчитывается по формуле: d = √((x₂ - x₁)² + (y₂ - y₁)²)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/stores_ekaterinburg.csv"

# %% [markdown]
# Получим *DataFrame* из CSV-файла по ссылке, указанной в переменной `sourse`, и отобразим его.

# %%
df = pl.read_csv(sourse)

print(df.head(4))

# %%
# Продолжите решение здесь
