# %% [markdown]
# # HW2. Чтение/Запись данных

# %% [markdown]
# Для записи в Excel Polars использует библиотеку *xlsxwriter*.
# Установим её.

# %%
# !pip install xlsxwriter

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl
import xlsxwriter

# %% [markdown]
# **Задание №1**.
#
# Загрузите набор данных, содержащий информацию о доле населения, использующего интернет по странам по ссылке из `url`.

# %%
url = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/share-of-individuals-using-the-internet.csv"

# Пишите код в данной ячейки
# ...

# %% [markdown]
# **Задание №2**.
#
# Посмотрите на *DataFrame*, выведите первые несколько строк. Убедитесь, что столбец с процентами имеет числовой тип (`pl.Float64` или `pl.Int64`), иначе дальнейшее форматирование работать не будет.
#
# Если стобец имеет иной тип данных (строка), то приведите его к числовому.

# %%
# Пишите код в данной ячейки
# ...

# %% [markdown]
# **Задание №3.**
#
# Запишите *DataFrame* в файл Excel с параметрами:
# - имя документа и его расширение - `"result.xlsx"`;
# - имя листа - `"data"`;
# - имя таблицы - `"internet"`;
# - формат ячеек:
#   - поле `Entity` - строковой тип данных,
#   - поле `Code` - строковой тип данных,
#   - поле `Year` - целое число,
#   - поле `Individuals using the Internet (% of population)` - проценты с одним знаком после запятой;
# - формат заголовка:
#   - жирный,
#   - шрифт - на выш выбор,
#   - размер шрифта - 14,
#   - цвет текста - красный;
# - включить автоматическую ширину столбцов.
#
# Дополнительно (по желанию) добавьте условное форматирование для столбца с процентами: например, выделите зелёным ячейки с долей > 80%.
#
# Подсказка: используйте параметр `conditional_formats`.
#
# Примечание. Чтобы полю `Individuals using the Internet (% of population)` задать формат процентов: если значения от нуля до единицы, то `"0.0%"`, иначе (если уже в процентах) `"0.0\%"`.

# %%
# Пишите код в данной ячейки
# ...

# %% [markdown]
# Ваш файл сохранится в папке `content` (по умолчанию сразу в ней должны оказаться).
#
# ![image.png](data:image/png;base64,...)
