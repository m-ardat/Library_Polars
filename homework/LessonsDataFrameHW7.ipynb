# %% [markdown]
# # HW7. Группировка и агрегация данных

# %% [markdown]
# ## Загрузка *DataFrame*

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/diamonds.csv"

# %% [markdown]
# Прочтём *DataFrame* из CSV-файла по ссылке, указанной в переменной sourse, и отобразим его.

# %%
df = pl.read_csv(sourse,columns=["carat", "cut", "color", "clarity", "depth", "table", "price", "x", "y", "z"])

print(df.head(4))
# Out:
# shape: (4, 10)
# ┌───────┬─────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut     ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---     ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str     ┆ str   ┆ str     ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal   ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good    ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# └───────┴─────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘

# %% [markdown]
# В этом домашнем задании будем работать с одним из классических наборов данных в статистике, содержащим информацию о бриллиантах. Описание можно посмотреть [здесь](https://www.kaggle.com/datasets/shivam2503/diamonds).

# %% [markdown]
# Краткое описание данных:
# - **price**: цена в долларах США
# - **carat**: вес алмаза
# - **cut**: качество огранки
# - **color**: цвет алмаза
# - **clarity**: измерение прозрачности алмаза
# - **x**: длина в мм
# - **y**: ширина в мм
# - **z**: глубина в мм
# - **depth**: глубина
# - **table**: ширина верхней части алмаза относительно самой широкой точки

# %% [markdown]
# ## Задачи

# %% [markdown]
# **Задание №1**.
#
# Сгруппируйте данные по качеству огранки (**cut**) и найдите среднюю цену (**price**) и средний вес (**carat**) для каждой категории.
# Результат должен содержать столбцы: `cut`, `avg_price`, `avg_carat`. Каждую метрику округлите до сотых.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №2**.
#
# Для каждой категории цвета (color) найдите минимальную и максимальную цену бриллианта.
# Выведите результат с понятными названиями столбцов: `color`, `min_price`, `max_price`.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задача №3**.
#
# Найдите у какой группы по типу огранки (**cut**) отношения среднего объёма к среднему весу (**carat**) по бриллиантам наибольшее.
#
# **Примечание**: объём = x * y * z.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задача №4.**
#
# Чему равен средний коэффициент вариации веса (**carat**) по всем группам **cut** и **color**? Ответ округлите до десятых.
#
# **Примечание**. `Коэффициент вариации = (std / mean) * 100`

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задача №5**.
#
# Сколько раз встречается самая частая комбинация **color** и **clarity** среди всех бриллиантов с `cut = "Ideal"`

# %%
# Продолжите написание кода в данной ячейки
#...
