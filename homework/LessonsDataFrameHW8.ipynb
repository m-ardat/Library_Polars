# %% [markdown]
# # HW8. Сортировка данных

# %% [markdown]
# ## Загрузка *DataFrame*

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/diamonds.csv"

# %% [markdown]
# Прочтём *DataFrame* из CSV-файла по ссылке, указанной в переменной sourse, и отобразим его.

# %%
df = pl.read_csv(sourse, columns=["carat", "cut", "color", "clarity", "depth", "table", "price", "x", "y", "z"])

print(df.head(4))
# Out:
# shape: (4, 10)
# ┌───────┬─────────┬───────┬─────────┬───┬───────┬──────┬──────┬──────┐
# │ carat ┆ cut     ┆ color ┆ clarity ┆ … ┆ price ┆ x    ┆ y    ┆ z    │
# │ ---   ┆ ---     ┆ ---   ┆ ---     ┆   ┆ ---   ┆ ---  ┆ ---  ┆ ---  │
# │ f64   ┆ str     ┆ str   ┆ str     ┆   ┆ i64   ┆ f64  ┆ f64  ┆ f64  │
# ╞═══════╪═════════╪═══════╪═════════╪═══╪═══════╪══════╪══════╪══════╡
# │ 0.23  ┆ Ideal   ┆ E     ┆ SI2     ┆ … ┆ 326   ┆ 3.95 ┆ 3.98 ┆ 2.43 │
# │ 0.21  ┆ Premium ┆ E     ┆ SI1     ┆ … ┆ 326   ┆ 3.89 ┆ 3.84 ┆ 2.31 │
# │ 0.23  ┆ Good    ┆ E     ┆ VS1     ┆ … ┆ 327   ┆ 4.05 ┆ 4.07 ┆ 2.31 │
# │ 0.29  ┆ Premium ┆ I     ┆ VS2     ┆ … ┆ 334   ┆ 4.2  ┆ 4.23 ┆ 2.63 │
# └───────┴─────────┴───────┴─────────┴───┴───────┴──────┴──────┴──────┘

# %% [markdown]
# В этом домашнем задании будем работать с одним из классических наборов данных в статистике, содержащим информацию о бриллиантах. Описание можно посмотреть [здесь](https://www.kaggle.com/datasets/shivam2503/diamonds).

# %% [markdown]
# Краткое описание данных:
# - **price**: цена в долларах США
# - **carat**: вес алмаза
# - **cut**: качество огранки
# - **color**: цвет алмаза
# - **clarity**: измерение прозрачности алмаза
# - **x**: длина в мм
# - **y**: ширина в мм
# - **z**: глубина в мм
# - **depth**: глубина
# - **table**: ширина верхней части алмаза относительно самой широкой точки

# %% [markdown]
# ## Задачи

# %% [markdown]
# **Задание №1**.
#
# Найдите среднюю цену бриллиантов в группе с самым высоким средним price.
#
# Условия:
#
# - Рассматривайте только бриллианты с cut = "Ideal" или cut = "Premium";
# - Отфильтруйте бриллианты с carat > 1.0;
# - Разделите их на три группы по весу:
#   - первая группа: вес меньше 1.3,
#   - вторая группа: вес меньше 1.7,
#   - третья группа: остальные;
# - Для каждой группы посчитайте среднюю цену;
# - Найдите максимальную из этих средних цен;
# - Верните округлённое до целого числа значение.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №2**. Лучшая комбинация качества по доходности на карат.
#
# Найдите первые 3 символа от строки **color** + **clarity** для комбинации с максимальной доходностью (`total_price / total_carat`), где `price > 1000`, `x > 5`.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №3**.
#
# Найдите объём (x * y * z) самого большого (по объёму) бриллианта среди 5 самых дешёвых с `cut = "Premium"` и `color = "J"`. Ответ округлите до десятых.

# %%
# Продолжите написание кода в данной ячейки
#...
