# %% [markdown]
# # HW3. Фильтрация данных

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/Sales_with_NaNs_v1.3.csv"

# %% [markdown]
# Прочтём *DataFrame* из CSV-файла по ссылке, указанной в переменной `sourse`, и отобразим его.

# %%
df = pl.read_csv(sourse)

print(df.head(4))

# %% [markdown]
# Наборы данных содержит информацию о продажах и уровне удовлетворённости клиентов до и после вмешательства, а также данные о покупках в контрольной и экспериментальной группах. Описание можно посмотреть [здесь](https://www.kaggle.com/datasets/matinmahmoudi/sales-and-satisfaction/data).

# %% [markdown]
# Краткое описание данных:
# - **Group**: группа
# - **Customer_Segment**: классификация клиентов в зависимости от их "ценности"
# - **Sales_Before**: показатели продаж до вмешательства
# - **Sales_After**: показатели продаж после вмешательства
# - **Customer_Satisfaction_Before**: Показпоказатели удовлетворённости клиентов до вмешательства.
# - **Customer_Satisfaction_After**: Показпоказатели удовлетворённости клиентов после вмешательства.
# - **Purchase_Made**: Указывает, была ли совершена покупка после вмешательства

# %% [markdown]
# **Задание №1**.
#
# Необходимо найти показатель удовлетворённости клиентов после вмешательства (`Customer_Satisfaction_After`) контрольной группы (`Group = 'Control'`), где покупка была совершена (`Purchase_Made = 'Yes'`) и показатели продаж после вмешательства (`Sales_After`) не пустые. Далее методами *polars DataFrame* найдите медиану результирующего набора данных. Ответ округлите до целого числа.

# %%
with pl.SQLContext(t_sales=df, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)

# %% [markdown]
# **Задание №2**.
#
# Найдите клиентов из группы `"Treatment"`, у которых удовлетворённость до (`Customer_Satisfaction_Before`) от 60 до 80 (границы включены), и выведите только столбцы: `Group`, `Customer_Segment`, `Customer_Satisfaction_Before`. Далее методами *polars DataFrame* сгруппируйте данные по полю `Customer_Segment` и вычислите медиану для каждого сегмента. Найдите топ 1 по возрастанию (наименьшее значение) сегмент по медиане. На экран выведите группу и её медиану. Медианное значение округлите до сотых.

# %%
# Продолжите написание кода в данной ячейки
with pl.SQLContext(t_sales=df, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)

    # Продолжите написание кода в данной ячейки

# %% [markdown]
# **Задание №3**.
#
# Выберите клиентов, у которых удовлетворённость после (`Customer_Satisfaction_After`) не указана (равна `NULL`). Выведите все столбцы. Сколько строк в результирующем наборе?

# %%
# Продолжите написание кода в данной ячейки
with pl.SQLContext(t_sales=df, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)

print(result)

# %% [markdown]
# **Задание №4**.
#
# Найдите всех клиентов из сегментов `'High Value'` ИЛИ `'Medium Value'`, которые НЕ совершили покупку (`Purchase_Made = 'No'`). Отсортируйте  по убыванию сначала по `Customer_Segment`, затем по `Sales_Before` по убыванию. Сколько таких клиентов?

# %%
# Продолжите написание кода в данной ячейки
with pl.SQLContext(t_sales=df, eager=True) as ctx:
    result = ctx.execute("""
        -- Продолжите написание кода здесь
    """)

print(result)
