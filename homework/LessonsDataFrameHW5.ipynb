# %% [markdown]
# # HW5. Очистка данных

# %% [markdown]
# Импорт необходимых библиотек

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/Sales_with_NaNs_v1.3.csv"

# %% [markdown]
# Прочтём *DataFrame* из CSV-файла по ссылке, указанной в переменной `sourse`, и отобразим его.

# %%
df = pl.read_csv(sourse)

print(df.head(4))
# Out:
# shape: (4, 7)
# ┌───────────┬──────────────┬──────────────┬─────────────┬──────────────┬─────────────┬─────────────┐
# │ Group     ┆ Customer_Seg ┆ Sales_Before ┆ Sales_After ┆ Customer_Sat ┆ Customer_Sa ┆ Purchase_Ma │
# │ ---       ┆ ment         ┆ ---          ┆ ---         ┆ isfaction_Be ┆ tisfaction_ ┆ de          │
# │ str       ┆ ---          ┆ f64          ┆ f64         ┆ fore         ┆ After       ┆ ---         │
# │           ┆ str          ┆              ┆             ┆ ---          ┆ ---         ┆ str         │
# │           ┆              ┆              ┆             ┆ f64          ┆ f64         ┆             │
# ╞═══════════╪══════════════╪══════════════╪═════════════╪══════════════╪═════════════╪═════════════╡
# │ Control   ┆ High Value   ┆ 240.548359   ┆ 300.007568  ┆ 74.684767    ┆ null        ┆ No          │
# │ Treatment ┆ High Value   ┆ 246.862114   ┆ 381.337555  ┆ 100.0        ┆ 100.0       ┆ Yes         │
# │ Control   ┆ High Value   ┆ 156.978084   ┆ 179.330464  ┆ 98.780735    ┆ 100.0       ┆ No          │
# │ Control   ┆ Medium Value ┆ 192.126708   ┆ 229.278031  ┆ 49.333766    ┆ 39.811841   ┆ Yes         │
# └───────────┴──────────────┴──────────────┴─────────────┴──────────────┴─────────────┴─────────────┘

# %% [markdown]
# Наборы данных содержит информацию о продажах и уровне удовлетворённости клиентов до и после вмешательства, а также данные о покупках в контрольной и экспериментальной группах. Описание можно посмотреть [здесь](https://www.kaggle.com/datasets/matinmahmoudi/sales-and-satisfaction/data).

# %% [markdown]
# Краткое описание данных:
# - **Group**: группа
# - **Customer_Segment**: классификация клиентов в зависимости от их "ценности"
# - **Sales_Before**: показатели продаж до вмешательства
# - **Sales_After**: показатели продаж после вмешательства
# - **Customer_Sattisfaction_Before**: Показпоказатели удовлетворённости клиентов до вмешательства.
# - **Customer_Sattisfaction_After**: Показпоказатели удовлетворённости клиентов после вмешательства.
# - **Purchase_Made**: Указывает, была ли совершена покупка после вмешательства

# %% [markdown]
# **Задание №1**.
#
# Удалите столбец `Purchase_Made` из *DataFrame*.
# Сохраните изменения в исходный *DataFrame*.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №2**.
#
# Выберите только строки, относящиеся к **Treatment**-группе.
# Сохраните результат в переменную treatment_df.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №3**.
#
# Выведите количество пропущенных значений (null) в каждом столбце в *DataFrame*.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №4**.
#
# Удалите все строки, где оба значения `Sales_Before` и `Sales_After` — **null**.
# Сохраните результат в переменную `df_cleaned`.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №5**.
#
# Заполните пропущенные значения в столбце `Customer_Satisfaction_After` медианным значением по группе **Control** для *DataFrame*.После этого найдите среднее значение данной колонки. Ответ округлите до сотых.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №6**.
#
# Проверить, есть ли полностью дублированные строки в *DataFrame*. Выведите их количество.

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №7**.
#
# Удалить строки, где есть пропущенные значения, и запишите в *DataFrame*. Сколько строк осталось?

# %%
# Продолжите написание кода в данной ячейки
# ...

# %% [markdown]
# **Задание №8**.
#
# Создайте "пустую" копию структуры в переменную `empty_df` и проверьте, что он действительно пустой.

# %%
# Продолжите написание кода в данной ячейки
# ...
