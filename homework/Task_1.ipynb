# %% [markdown]
# **Задача №1. Двойки у отличников.**
#
# Найдите имена и количество двоек у тех учеников, у которых больше 370 пятерок. Соответственно надо получить табличку с именем и количеством двоек.

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl

# %% [markdown]
# Источник данных

# %%
sourse = "https://raw.githubusercontent.com/m-ardat/Library_Polars/main/dataset/school.csv"

# %% [markdown]
# Получим *DataFrame* из CSV-файла по ссылке, указанной в переменной `sourse`, и отобразим его.

# %%
df = pl.read_csv(sourse)

print(df.head(4))

# %%
# Продолжите решение здесь
