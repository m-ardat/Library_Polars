# %% [markdown]
# # HW2.Методы, параметры и атрибуты Series

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import polars as pl
import numpy as np

# %% [markdown]
# Возьмём данные по проходным баллам поступления на бакалавриат по специальностям 2021 года в НИУ "МЭИ".
#
# Ссылка: https://mpei.ru/admission/bachelor/pages/passing_scores.aspx

# %%
score = [
  203,
  186,
  172,
  187,
  179,
  204,
  251,
  205,
  252,
  233,
  191,
  186,
  239,
  246,
  173,
  199,
  258,
  259,
  207,
  221,
  264,
  240,
  235,
  172,
  253,
  178,
  171,
  241,
  227,
  206,
  183,
  179
]

# %% [markdown]
# **Задание №1**. Создайте объект *Series* с именем `"score"` и выведете на экран имя серии.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №2**. Найдите среднее и медианное значения. На экран выведете значение меньшей метрики.

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №3**. Какой процент составляет разница между максимальным и минимальным значением баллов относительно минимального значения? Ответ округлите до целого числа.
#
# **Примечание.** Формула для расчётов:
# $$\text{Процент превышения} = \left( \frac{\text{Максимум} - \text{Минимум}}{\text{Минимум}} \right) \times 100\%
# $$

# %%
# Продолжите написание кода в данной ячейки
#...

# %% [markdown]
# **Задание №4**. Посчитайте количество уникальных проходных баллов и сравните его с общим количеством элементов. Какую долю от всех записей составляют уникальные значения? Ответ округлите до двух знаков после запятой.

# %%
# Продолжите написание кода в данной ячейки
#...
